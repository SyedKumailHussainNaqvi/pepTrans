# %%
# %run "/model/imports.py"
# %run "/model/Binary_Classification_pepTrans_module.py" 
# %run "/model/Binding_Site_pepTrans_module.py"
# %run "/model/Binding_Affinity_pepTrans_Module.py"
# %run "/model/Cross_Validation_pepTrans_Binding_Sites.py"
# %run "pepTrans.py"
# %run "run_pepTrans_Jupyter.py"
import warnings
import logging
warnings.filterwarnings("ignore")
logging.getLogger('tensorflow').setLevel(logging.ERROR)
warnings.filterwarnings("ignore", message=".*TensorFlow Addons.*")
warnings.filterwarnings("ignore", message=".*you are currently using is 2.9.0 and is not supported.*")

# %%
args = SimpleNamespace(
    mode='b',
    csv='/NA_Updated_dataset.csv',
    vas_csv=None,
    label='Label',
    train_h5=None,
    test_h5=None,
    gpu='5'
)
run_pepTrans(args)
# Out:
# Using GPU 5
# Peptide–Protein Binary Interaction: pepTrans loading for training with 5-fold cross-validation...
#
# Training pepTrans model on fold 1
# Epoch 1/5000
# 279/279 [==============================] - 19s 66ms/step - loss: 1.4928 - accuracy: 0.6042 - auc_1: 0.6483 - val_loss: 1.1079 - val_accuracy: 0.6633 - val_auc_1: 0.7535
# Epoch 2/5000
# 279/279 [==============================] - 19s 69ms/step - loss: 0.9915 - accuracy: 0.6890 - auc_1: 0.7717 - val_loss: 0.8959 - val_accuracy: 0.7060 - val_auc_1: 0.7955
# Epoch 3/5000
# 279/279 [==============================] - 19s 66ms/step - loss: 0.8404 - accuracy: 0.7138 - auc_1: 0.8058 - val_loss: 0.8268 - val_accuracy: 0.6916 - val_auc_1: 0.8172
# Epoch 4/5000
# 279/279 [==============================] - 19s 68ms/step - loss: 0.7686 - accuracy: 0.7365 - auc_1: 0.8295 - val_loss: 0.7371 - val_accuracy: 0.7566 - val_auc_1: 0.8360
# Epoch 5/5000
# ...
